# %%
import pandas as pd

# %%
df = pd.read_csv("BlackFriday.csv")
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 537572  1004737  P00193542      M  36-45          16             C
# 537573  1004737  P00111142      M  36-45          16             C
# 537574  1004737  P00345942      M  36-45          16             C
# 537575  1004737  P00285842      M  36-45          16             C
# 537576  1004737  P00118242      M  36-45          16             C
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
#Analayzing Gender
#how many rows are there for male and female
len(df[df['Gender'] == 'M']), len(df[df['Gender'] == 'F'])
# Out:
# (405380, 132197)

# %%
#Representing it i graph
data = pd.DataFrame({'Ratio' :[len(df[df['Gender'] == 'M']), len(df[df['Gender'] == 'F'])]} , index = ['Male','Female'])

# %%
data.plot.pie(y = 'Ratio')
# Out:
# <Axes: ylabel='Ratio'>

# %%
#using groupby function 
df.groupby('Gender').size().plot(kind = 'bar', figsize = (6,6))
# Out:
# <Axes: xlabel='Gender'>

# %%
#finding how much sum of money did each gender spent
df.groupby('Gender').sum()['Purchase']
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_51036\2586698306.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Gender').sum()['Purchase']
# Gender
# F    1164624021
# M    3853044357
# Name: Purchase, dtype: int64

# %%
#finding the average of how much they spend
df.groupby('Gender').mean()['Purchase'].plot(kind = 'pie', autopct = "%0.1f")
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_51036\2118105210.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Gender').mean()['Purchase'].plot(kind = 'pie', autopct = "%0.1f")
# <Axes: ylabel='Purchase'>

# %% [markdown]
# # Analyzing multiple column

# %%
import seaborn as sns

# %%
sns.set(rc = {'figure.figsize' : (12,6)})
sns.countplot(x = "Age", hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.set(rc = {'figure.figsize' : (12,6)})
sns.countplot(x = "Gender", hue = 'Age', data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
#occupation and product analysis
sns.countplot(x = df['Stay_In_Current_City_Years'])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>
